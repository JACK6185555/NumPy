# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('student_performance_large_dataset.csv')
df
# Out:
#      Student_ID  Age  Gender  Study_Hours_per_Week Preferred_Learning_Style  \
# 0        S00001   18  Female                    48              Kinesthetic
# 1        S00002   29  Female                    30          Reading/Writing
# 2        S00003   20  Female                    47              Kinesthetic
# 3        S00004   23  Female                    13                 Auditory
# 4        S00005   19  Female                    24                 Auditory
# ...         ...  ...     ...                   ...                      ...
# 9995     S09996   20    Male                    30                 Auditory
# 9996     S09997   23  Female                    16                   Visual
# 9997     S09998   26    Male                    23                   Visual
# 9998     S09999   18    Male                    41          Reading/Writing
# 9999     S10000   24    Male                     8                   Visual
#
# ...

# %%
Gender_Final_Grade=df.groupby('Gender')['Final_Grade'].value_counts()
Gender_Final_Grade
# Out:
# Gender  Final_Grade
# Female  A              1302
#         B              1197
#         D              1186
#         C              1161
# Male    A              1262
#         B              1168
#         C              1168
#         D              1150
# Other   A               114
#         C               111
#         D                91
#         B                90
# Name: count, dtype: int64

# %%
labels=['Female','Male','Other']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 3
#       1 labels=['Female','Male','Other']
# ----> 3 plt.bar(labels,Gender_Final_Grade,color='r')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\matplotlib\pyplot.py:2739, in bar(x, height, width, bottom, align, data, **kwargs)
#    2728 @_copy_docstring_and_deprecators(Axes.bar)
#    2729 def bar(
#    2730     x: float | ArrayLike,
#    (...)
#    2737     **kwargs,
#    2738 ) -> BarContainer:
# -> 2739     return gca().bar(
#    2740         x,
#    2741         height,
#    2742         width=width,
#    2743         bottom=bottom,
#    2744         align=align,
#    2745         **({"data": data} if data is not None else {}),
#    2746         **kwargs,
#    2747     )
#
# ...
