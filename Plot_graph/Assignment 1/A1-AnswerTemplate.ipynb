# %% [markdown]
# ## CCIT4092 Data Visualization 2024/2025
# ## Assignment 1 (Answer Template)

# %% [markdown]
# #### Student Name:
# #### Student ID:
#
# <i>You can add additional cells in this Jupyter Notebook, if necessary.</i>

# %% [markdown]
# ### Task 1: Data collection and cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# (1) - Collect and extract the data from the relevant website;
### Your code here ### 
df=pd.read_csv('disney_plus_titles.csv')
df
# Out:
#      show_id     type                                             title  \
# 0         s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1         s2    Movie                            Ernest Saves Christmas
# 2         s3    Movie                      Ice Age: A Mammoth Christmas
# 3         s4    Movie                        The Queen Family Singalong
# 4         s5  TV Show                             The Beatles: Get Back
# ...      ...      ...                                               ...
# 1445   s1446    Movie                          X-Men Origins: Wolverine
# 1446   s1447    Movie    Night at the Museum: Battle of the Smithsonian
# 1447   s1448    Movie                                   Eddie the Eagle
# 1448   s1449    Movie                              Bend It Like Beckham
# 1449   s1450    Movie             Captain Sparky vs. The Flying Saucers
#
#                                director  \
# 0     Alonso Ramirez Ramos, Dave Wasson
# ...

# %%
# (2a) What is the data structure (data type) you have used to store the data (e.g., DataFrame, Series, Array, List)?
### Your code here ### 
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# (2b) How many rows and columns are there in the data? 
### Your code here ### 
df.shape
# Out:
# (1450, 12)

# %%
# (2c) What is the dimension of the data?
### Your code here ### 
df.ndim
# Out:
# 2

# %%
# (2d) What are the data types (e.g., integer, float) of the data?
### Your code here ### 
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
# (2e) Are there any null values or non-numeric data in your dataset?
### Your code here ### 
df.isnull().values.any()
# Out:
# True

# %%
df.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False  False     True       False
# 1       False  False  False     False  False     True       False
# 2       False  False  False     False  False    False       False
# 3       False  False  False     False  False     True       False
# 4       False  False  False      True  False     True       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 1445    False  False  False     False  False    False       False
# 1446    False  False  False     False  False    False       False
# 1447    False  False  False     False  False    False       False
# 1448    False  False  False     False  False    False       False
# 1449    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
# 3. Perform data cleaning. You are suggested to write functions for the data cleaning process. 
# You can get additional cells in this Jupyter Notebook, if necessary

#First,Use the drop_duplicates() method to remove duplicates, considering all columns by default
df=df.drop_duplicates()

#Directly delete the number of columns containing Nan values
df=df.fillna('NaN value')
df
# Out:
#      show_id     type                                             title  \
# 0         s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1         s2    Movie                            Ernest Saves Christmas
# 2         s3    Movie                      Ice Age: A Mammoth Christmas
# 3         s4    Movie                        The Queen Family Singalong
# 4         s5  TV Show                             The Beatles: Get Back
# ...      ...      ...                                               ...
# 1445   s1446    Movie                          X-Men Origins: Wolverine
# 1446   s1447    Movie    Night at the Museum: Battle of the Smithsonian
# 1447   s1448    Movie                                   Eddie the Eagle
# 1448   s1449    Movie                              Bend It Like Beckham
# 1449   s1450    Movie             Captain Sparky vs. The Flying Saucers
#
#                                director  \
# 0     Alonso Ramirez Ramos, Dave Wasson
# ...

# %% [markdown]
# ### Task 2: Data Processing and Visualization

# %% [markdown]
# #### 1. Display all movie titles released after 2000

# %% [markdown]
# #### 2. Visualize the number of movies per category released after the year 2000.

# %% [markdown]
# #### 3. Visualize the number of movies released after the year 2000 for the top three categories.
