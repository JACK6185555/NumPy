# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

data=pd.read_excel('Depressive disorders.xlsx')
data
# Out:
#                         Unnamed: 0   2000   2001   2002   2003   2004   2005  \
# 0                      Afghanistan  656.4  652.0  649.4  648.0  648.4  650.5
# 1                          Albania  379.6  385.8  392.2  398.6  404.8  410.4
# 2                          Algeria  691.5  700.5  708.8  716.4  722.4  727.9
# 3                   American Samoa  336.5  337.3  338.5  339.3  340.3  341.1
# 4                          Andorra  764.6  764.6  763.6  764.3  763.2  760.6
# ..                             ...    ...    ...    ...    ...    ...    ...
# 218          South-East Asia (WHO)  600.1  606.1  614.4  623.2  631.4  637.1
# 219        Sub-Saharan Africa (WB)  598.0  598.0  597.8  597.4  597.0  596.3
# 220  Upper-middle-income countries  536.8  540.9  545.9  551.2  556.1  559.7
# 221          Western Pacific (WHO)  471.3  474.4  478.8  483.7  488.5  491.9
# 222                          World  600.6  604.1  608.0  612.0  615.8  618.5
#
# ...

# %%
data.rename(columns={'Unnamed: 0': 'Country'}, inplace=True)

data_melted = pd.melt(data, id_vars=['Country'], var_name='Year', value_name='Value')

data_melted['Year'] = data_melted['Year'].astype(int)

specific_countries = ['World', 'North America (WB)', 'Europe & Central Asia (WB)', 'Japan', 'Canada', 'Americas (WHO)', 'European Region (WHO)','Western Pacific (WHO)']
data_filtered = data_melted[(data_melted['Year'] >= 2000) & (data_melted['Year'] <= 2021) & data_melted['Country'].isin(specific_countries)]

plt.figure(figsize=(15, 9))
for country, group in data_filtered.groupby('Country'):
    plt.plot(group['Year'], group['Value'], marker='o', linestyle='-', label=country)
plt.title('Depressive Disorders Values from 2000 to 2021 for Specific Countries')
plt.xlabel('Year')
plt.ylabel('Value')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# %%
data.rename(columns={'Unnamed: 0': 'Country'}, inplace=True)

data_melted = pd.melt(data, id_vars=['Country'], var_name='Year', value_name='Value')

data_melted['Year'] = data_melted['Year'].astype(int)

specific_countries = ['China', 'Thailand', 'Vietnam', 'Japan', 'South Korea']
data_filtered = data_melted[(data_melted['Year'] >= 2000) & (data_melted['Year'] <= 2021) & data_melted['Country'].isin(specific_countries)]

plt.figure(figsize=(15, 9))
for country, group in data_filtered.groupby('Country'):
    plt.plot(group['Year'], group['Value'], marker='o', linestyle='-', label=country)
plt.title('Depressive Disorders Values from 2000 to 2021 for Countries in Asia')
plt.xlabel('Year')
plt.ylabel('Value')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# %%
data.rename(columns={'Unnamed: 0': 'Country'}, inplace=True)

data_melted = pd.melt(data, id_vars=['Country'], var_name='Year', value_name='Value')

data_melted['Year'] = data_melted['Year'].astype(int)

specific_countries = ['Benin', 'Botswana', 'Kenya', 'Egypt', 'South Africa']
data_filtered = data_melted[(data_melted['Year'] >= 2000) & (data_melted['Year'] <= 2021) & data_melted['Country'].isin(specific_countries)]

plt.figure(figsize=(15, 9))
for country, group in data_filtered.groupby('Country'):
    plt.plot(group['Year'], group['Value'], marker='o', linestyle='-', label=country)
plt.title('Depressive Disorders Values from 2000 to 2021 for Countries in Africa')
plt.xlabel('Year')
plt.ylabel('Value')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# %%
data.rename(columns={'Unnamed: 0': 'Country'}, inplace=True)

data_melted = pd.melt(data, id_vars=['Country'], var_name='Year', value_name='Value')

data_melted['Year'] = data_melted['Year'].astype(int)

specific_countries = ['United States', 'Mexico', 'Canada', 'Haiti', 'Guatemala']
data_filtered = data_melted[(data_melted['Year'] >= 2000) & (data_melted['Year'] <= 2021) & data_melted['Country'].isin(specific_countries)]

plt.figure(figsize=(15, 9))
for country, group in data_filtered.groupby('Country'):
    plt.plot(group['Year'], group['Value'], marker='o', linestyle='-', label=country)
plt.title('Depressive Disorders Values from 2000 to 2021 for Countries in North America')
plt.xlabel('Year')
plt.ylabel('Value')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# %%
data.rename(columns={'Unnamed: 0': 'Country'}, inplace=True)

data_melted = pd.melt(data, id_vars=['Country'], var_name='Year', value_name='Value')

data_melted['Year'] = data_melted['Year'].astype(int)

specific_countries = ['Peru', 'Chile', 'Argentina', 'Brazil', 'Colombia']
data_filtered = data_melted[(data_melted['Year'] >= 2000) & (data_melted['Year'] <= 2021) & data_melted['Country'].isin(specific_countries)]

plt.figure(figsize=(15, 9))
for country, group in data_filtered.groupby('Country'):
    plt.plot(group['Year'], group['Value'], marker='o', linestyle='-', label=country)
plt.title('Depressive Disorders Values from 2000 to 2021 for Countries in South America')
plt.xlabel('Year')
plt.ylabel('Value')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# %%
data.rename(columns={'Unnamed: 0': 'Country'}, inplace=True)

data_melted = pd.melt(data, id_vars=['Country'], var_name='Year', value_name='Value')

data_melted['Year'] = data_melted['Year'].astype(int)

specific_countries = ['France', 'United Kingdom', 'New Zealand', 'Norway', 'Australia']
data_filtered = data_melted[(data_melted['Year'] >= 2000) & (data_melted['Year'] <= 2021) & data_melted['Country'].isin(specific_countries)]

plt.figure(figsize=(15, 9))
for country, group in data_filtered.groupby('Country'):
    plt.plot(group['Year'], group['Value'], marker='o', linestyle='-', label=country)
plt.title('Depressive Disorders Values from 2000 to 2021 for Countries in Antarctica')
plt.xlabel('Year')
plt.ylabel('Value')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# %%
data.rename(columns={'Unnamed: 0': 'Country'}, inplace=True)

data_melted = pd.melt(data, id_vars=['Country'], var_name='Year', value_name='Value')

data_melted['Year'] = data_melted['Year'].astype(int)

specific_countries = ['Austria', 'Germany', 'Spain', 'Italy', 'Sweden']
data_filtered = data_melted[(data_melted['Year'] >= 2000) & (data_melted['Year'] <= 2021) & data_melted['Country'].isin(specific_countries)]

plt.figure(figsize=(15, 9))
for country, group in data_filtered.groupby('Country'):
    plt.plot(group['Year'], group['Value'], marker='o', linestyle='-', label=country)
plt.title('Depressive Disorders Values from 2000 to 2021 for Countries in Europe')
plt.xlabel('Year')
plt.ylabel('Value')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# %%
data.rename(columns={'Unnamed: 0': 'Country'}, inplace=True)

data_melted = pd.melt(data, id_vars=['Country'], var_name='Year', value_name='Value')

data_melted['Year'] = data_melted['Year'].astype(int)

specific_countries = ['Nauru', 'Samoa', 'Fiji', 'Marshall Islands', 'Palau']
data_filtered = data_melted[(data_melted['Year'] >= 2000) & (data_melted['Year'] <= 2021) & data_melted['Country'].isin(specific_countries)]

plt.figure(figsize=(15, 9))
for country, group in data_filtered.groupby('Country'):
    plt.plot(group['Year'], group['Value'], marker='o', linestyle='-', label=country)
plt.title('Depressive Disorders Values from 2000 to 2021 for Countries in Australia')
plt.xlabel('Year')
plt.ylabel('Value')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


specific_countries = ['World']
specific_who = ['Western Pacific (WHO)']

df_world = data_melted[
    (data_melted['Year'].between(2000, 2021)) & 
    (data_melted['Country'].isin(specific_countries))
]

df_who = data_melted[
    (data_melted['Year'].between(2000, 2021)) & 
    (data_melted['Country'].isin(specific_who))
]

combined_df = pd.concat([df_world, df_who])

pivot_df = combined_df.pivot(index='Year', columns='Country', values='Value')


plt.figure(figsize=(12, 6))
bar_plot = pivot_df.plot(kind='bar', width=0.8, colormap='viridis', ax=plt.gca())

plt.title('Depressive Disorders Values from 2000 to 2021', fontsize=14, pad=20)
plt.xlabel('Year', fontsize=12, labelpad=10)
plt.ylabel('Value', fontsize=12, labelpad=10)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', alpha=0.3)

plt.legend(title='Country', bbox_to_anchor=(1.02, 1), borderaxespad=0, fontsize=10)

plt.tight_layout()
plt.show()
