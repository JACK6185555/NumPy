# %% [markdown]
# ## CCIT4092 Data Visualization 2024/2025
# ## Assignment 2 (Answer Template)

# %% [markdown]
# #### Student Name: Wong Ka Lok
# #### Student ID: 20242577
#
# <i>You can add additional cells in this Jupyter Notebook, if necessary.</i>

# %% [markdown]
# ### Task 1: Data collection and cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# (1) - Collect and extract the data from the relevant website;
### Your code here ### 
df=pd.read_csv('EmojiDietNutritionalData.csv')
df.head()
# Out:
#          name emoji  Calories (kcal)  Carbohydrates (g)  Total Sugar (g)  \
# 0      grapes     🍇             0.69             0.1810           0.1548
# 1       melon     🍈             0.28             0.0658           0.0569
# 2  watermelon     🍉             0.30             0.0755           0.0620
# 3   tangerine     🍊             0.53             0.1334           0.1058
# 4       lemon     🍋             0.29             0.0932           0.0250
#
#    Protein (g)  Total Fat (g)  Saturated Fat (g)  \
# 0       0.0072         0.0016            0.00054
# 1       0.0111         0.0010            0.00025
# 2       0.0061         0.0015            0.00016
# 3       0.0081         0.0031            0.00039
# 4       0.0110         0.0030            0.00039
#
#    Monounsaturated Fat (g)         Polyunsaturated Fat (g)  ...  Calcium (g)  \
# 0                         0.00007                  0.00048  ...         0.10
# ...

# %%
# (2a) What is the data structure (data type) you have used to store the data (e.g., DataFrame, Series, Array, List)?
### Your code here ### 
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# (2b) How many rows and columns are there in the data? 
### Your code here ### 
df.shape
# Out:
# (58, 35)

# %%
# (2c) What is the dimension of the data?
### Your code here ### 
df.ndim
# Out:
# 2

# %%
# (2d) What are the data types (e.g., integer, float) of the data?
### Your code here ### 
df.dtypes
# Out:
# name                               object
# emoji                              object
# Calories (kcal)                   float64
# Carbohydrates (g)                 float64
# Total Sugar (g)                   float64
# Protein (g)                       float64
# Total Fat (g)                     float64
# Saturated Fat (g)                 float64
# Monounsaturated Fat (g)           float64
# Polyunsaturated Fat (g)           float64
# Total Fiber (g)                   float64
# Cholesterol (mg)                  float64
# Vitamin B6 (mg)                   float64
# Vitamin A (IU)                    float64
# Vitamin B12 (ug)                  float64
# Vitamin C (mg)                    float64
# Vitamin D (IU)                    float64
# Vitamin E (IU)                    float64
# Vitamin K (ug)                    float64
# Thiamin (mg)                      float64
# Riboflavin (mg)                   float64
# Niacin (mg)                       float64
# ...

# %%
# (2e) Are there any null values or non-numeric data in your dataset?
### Your code here ### 
df.isnull().values.any()
# Out:
# False

# %%
# 3. Perform data cleaning. You are suggested to write functions for the data cleaning process. 
# You can get additional cells in this Jupyter Notebook, if necessary

#First,Use the drop_duplicates() method to remove duplicates, considering all columns by default
df=df.drop_duplicates()


#Next, drop the column of emoji from the DataFrame 
del df['emoji']


df.head()
# Out:
#          name  Calories (kcal)  Carbohydrates (g)  Total Sugar (g)  \
# 0      grapes             0.69             0.1810           0.1548
# 1       melon             0.28             0.0658           0.0569
# 2  watermelon             0.30             0.0755           0.0620
# 3   tangerine             0.53             0.1334           0.1058
# 4       lemon             0.29             0.0932           0.0250
#
#    Protein (g)  Total Fat (g)  Saturated Fat (g)  \
# 0       0.0072         0.0016            0.00054
# 1       0.0111         0.0010            0.00025
# 2       0.0061         0.0015            0.00016
# 3       0.0081         0.0031            0.00039
# 4       0.0110         0.0030            0.00039
#
#    Monounsaturated Fat (g)         Polyunsaturated Fat (g)  Total Fiber (g)  \
# 0                         0.00007                  0.00048            0.009
# 1                         0.00002                  0.00039            0.009
# ...

# %% [markdown]
# ### Task 2: Data Processing and Visualization

# %% [markdown]
# #### 1. Visualize the correlation between the nutrients.

# %%
import seaborn as sns

corr_matrix=df.select_dtypes(include=['number']).corr()

# %%
sns.heatmap(corr_matrix, cmap="coolwarm")
plt.title("Correlation Matrix of Nutrients")
plt.show()

# %% [markdown]
# #### 2. Visualize the nutritional content of a croissant.

# %%
croissant = df[df['name'] == 'croissant'].select_dtypes(include=['number'])


croissant_t = croissant.T
croissant_t.columns = ['value']
croissant_sorted = croissant_t.sort_values(by='value', ascending=False)
colors = ['#ff9999' if i == 0 else '#cce5ff' for i in range(len(croissant_sorted))]

# %%
plt.figure(figsize=(12, 5))
sns.barplot(x=croissant_sorted.index, y=croissant_sorted['value'], palette=colors)
plt.xticks(rotation=90, ha='right',fontsize=7.4)
plt.title("Nutritional Content of a Croissant")
plt.xlabel('The nutritional content per')
plt.ylabel("Amount per Serving")
# Out:
# C:\Users\kalok\AppData\Local\Temp\ipykernel_4768\1822866402.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=croissant_sorted.index, y=croissant_sorted['value'], palette=colors)
# Text(0, 0.5, 'Amount per Serving')

# %% [markdown]
# #### 3. Visualize the Vitamin A content across different food items.

# %%
vitamin_a_sorted = df.sort_values('Vitamin A (IU)', ascending=False)

# %%
plt.figure(figsize=(12, 8))

sns.barplot(x='Vitamin A (IU)', y='name', data=vitamin_a_sorted, palette='viridis')

plt.title('Vitamin A content of each food item (IU/g)', fontsize=16)
plt.xlabel('Vitamin A (IU)', fontsize=12)
plt.ylabel('Food Item', fontsize=12)
plt.xticks(fontsize=9)
plt.yticks(fontsize=9)
sns.set_style("whitegrid")
# Out:
# C:\Users\kalok\AppData\Local\Temp\ipykernel_4768\2564196418.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Vitamin A (IU)', y='name', data=vitamin_a_sorted, palette='viridis')
