# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('personality_dataset.csv')
df
# Out:
#       Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0                  4.0         No                      4.0            6.0
# 1                  9.0        Yes                      0.0            0.0
# 2                  9.0        Yes                      1.0            2.0
# 3                  0.0         No                      6.0            7.0
# 4                  3.0         No                      9.0            4.0
# ...                ...        ...                      ...            ...
# 2895               3.0         No                      7.0            6.0
# 2896               3.0         No                      8.0            3.0
# 2897               4.0        Yes                      1.0            1.0
# 2898              11.0        Yes                      1.0            NaN
# 2899               3.0         No                      6.0            6.0
#
#      Drained_after_socializing  Friends_circle_size  Post_frequency  \
# ...

# %%
df.shape
# Out:
# (2900, 8)

# %%
df.info()
# Out:
# <bound method DataFrame.info of       Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0                  4.0         No                      4.0            6.0
# 1                  9.0        Yes                      0.0            0.0
# 2                  9.0        Yes                      1.0            2.0
# 3                  0.0         No                      6.0            7.0
# 4                  3.0         No                      9.0            4.0
# ...                ...        ...                      ...            ...
# 2895               3.0         No                      7.0            6.0
# 2896               3.0         No                      8.0            3.0
# 2897               4.0        Yes                      1.0            1.0
# 2898              11.0        Yes                      1.0            NaN
# 2899               3.0         No                      6.0            6.0
#
# ...

# %%
plt.figure(figsize=(12,10))
sns.countplot(x='Personality',data=df)
plt.title('Class Distrubistion of Personality Types')
plt.xlabel('Personality')
plt.ylabel('Count')
plt.show()

# %%
g=sns.PairGrid(df)
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
plt.show()
plt.close()

# %%
numeric_colums=['Time_spent_Alone', 'Social_event_attendance', 'Going_outside', 'Friends_circle_size', 'Post_frequency']

# %%
sns.heatmap(df[numeric_colums].corr(),annot=True,cmap='coolwarm',fmt='.2f')
plt.title('Correlation Heatmap of Numeric Features')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap of Numeric Features')

# %%
df.isnull().values.any()
# Out:
# True

# %%
df=df.dropna()

# %%
plt.figure(figsize=(12,10))
sns.countplot(x='Personality',data=df)
plt.title('Class Distrubistion of Personality Types')
plt.xlabel('Personality')
plt.ylabel('Count')
plt.show()

# %%
g=sns.PairGrid(df)
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
plt.show()
plt.close()

# %%
sns.heatmap(df[numeric_colums].corr(),annot=True,cmap='coolwarm',fmt='.2f')
plt.title('Correlation Heatmap of Numeric Features')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap of Numeric Features')

# %%
g=sns.PairGrid(df)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)
g.map_diag(sns.kdeplot)

# %%
df
# Out:
#       Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0                  4.0         No                      4.0            6.0
# 1                  9.0        Yes                      0.0            0.0
# 2                  9.0        Yes                      1.0            2.0
# 3                  0.0         No                      6.0            7.0
# 4                  3.0         No                      9.0            4.0
# ...                ...        ...                      ...            ...
# 2892               9.0        Yes                      2.0            0.0
# 2895               3.0         No                      7.0            6.0
# 2896               3.0         No                      8.0            3.0
# 2897               4.0        Yes                      1.0            1.0
# 2899               3.0         No                      6.0            6.0
#
#      Drained_after_socializing  Friends_circle_size  Post_frequency  \
# ...

# %%
sns.relplot(df,x='Friends_circle_size',y='Post_frequency',hue='Personality')

# %%
sns.catplot(x='Personality',y='Social_event_attendance',kind='violin',data=df)

# %%
sns.catplot(x='Personality',y='Friends_circle_size',hue='Stage_fear',data=df)

# %%
sns.displot(x='Friends_circle_size',hue='Personality',data=df)

# %%
sns.displot(x='Friends_circle_size',hue='Personality',multiple='stack',data=df)

# %%
sns.displot(df,x='Friends_circle_size',row='Personality')

# %%
sns.displot(df,x='Friends_circle_size',col='Personality')

# %%
sns.displot(df,x='Going_outside',hue='Personality',kind='kde')

# %%
sns.displot(df,x='Going_outside',hue='Personality',multiple='stack',kind='kde')

# %%
sns.relplot(df,x='Social_event_attendance',y='Friends_circle_size',hue='Stage_fear')
